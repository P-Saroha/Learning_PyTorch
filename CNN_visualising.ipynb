# %%
from keras.applications.vgg16 import VGG16
#Load the model
model = VGG16()
# Out:
# ...
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ...

# %%
from keras.utils import plot_model

plot_model(model)

# %%
for i in range(len(model.layers)):
	# check for convolutional layer
	if 'conv' not in model.layers[i].name:
		continue
	# get filter weights
	filters, biases = model.layers[i].get_weights()
	print("layer number",i,model.layers[i].name, filters.shape)
# Out:
# layer number 1 block1_conv1 (3, 3, 3, 64)
# layer number 2 block1_conv2 (3, 3, 64, 64)
# layer number 4 block2_conv1 (3, 3, 64, 128)
# layer number 5 block2_conv2 (3, 3, 128, 128)
# layer number 7 block3_conv1 (3, 3, 128, 256)
# layer number 8 block3_conv2 (3, 3, 256, 256)
# layer number 9 block3_conv3 (3, 3, 256, 256)
# layer number 11 block4_conv1 (3, 3, 256, 512)
# layer number 12 block4_conv2 (3, 3, 512, 512)
# layer number 13 block4_conv3 (3, 3, 512, 512)
# layer number 15 block5_conv1 (3, 3, 512, 512)
# layer number 16 block5_conv2 (3, 3, 512, 512)
# layer number 17 block5_conv3 (3, 3, 512, 512)

# %%
# retrieve weights from the second hidden layer
filters , bias = model.layers[1].get_weights()

# %%
# normalize filter values to 0-1 so we can visualize them
f_min, f_max = filters.min(), filters.max()
filters = (filters - f_min) / (f_max - f_min)

# %%
import matplotlib.pyplot as plt # Import the pyplot module from matplotlib and assign it to the alias 'plt'
n_filters =6
ix=1
fig = plt.figure(figsize=(15,10)) # Use 'plt' to access the 'figure' function
for i in range(n_filters):
    # get the filters
    f = filters[:,:,:,i]
    for j in range(3):
        # subplot for 6 filters and 3 channels
        plt.subplot(n_filters,3,ix) # Use 'plt' to access the 'subplot' function
        plt.imshow(f[:,:,j] ,cmap='gray') # Use 'plt' to access the 'imshow' function
        ix+=1
#plot the filters
plt.show() # Use 'plt' to access the 'show' function

# %%
from tensorflow import keras #import keras library

model = keras.models.Model(inputs=model.inputs , outputs=model.layers[1].output) # use keras.models.Model to access the model class

# %%
from tensorflow import keras
from keras.preprocessing.image import load_img, img_to_array
from keras.applications.vgg16 import preprocess_input
from numpy import expand_dims

# Load the image
image = load_img("/content/drive/MyDrive/STUDENT PHOTO (2).jpg", target_size=(224, 224))

# Convert the image to an array
image = img_to_array(image)

# Expand dimensions so that it represents a single 'sample'
image = expand_dims(image, axis=0)

# Preprocess the image
image = preprocess_input(image)

# %%
import matplotlib.pyplot as plt # Import the pyplot module from matplotlib and assign it to the alias 'plt'

#calculating features_map
features = model.predict(image)

fig = plt.figure(figsize=(20,15)) # Use 'plt' instead of 'pyplot'
for i in range(1,features.shape[3]+1):

    plt.subplot(8,8,i) # Use 'plt' instead of 'pyplot'
    plt.imshow(features[0,:,:,i-1] , cmap='gray') # Use 'plt' instead of 'pyplot'

plt.show() # Use 'plt' instead of 'pyplot'
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step

# %%
model2 = VGG16()

# %%
from keras.models import Model # Import the 'Model' class from keras.models

layer_index = [2, 5, 9, 13, 17]
outputs = [model2.layers[i].output for i in layer_index]

# Now you can use the Model class to create model3
model3 = Model(inputs=model2.inputs, outputs=outputs)

# %%
import matplotlib.pyplot as plt # Import the pyplot module from matplotlib and assign it to the alias 'plt'

feature_map = model3.predict(image)

for i,fmap in zip(layer_index,feature_map):
    fig = plt.figure(figsize=(20,15)) # Use 'plt' instead of 'pyplot'
    fig.suptitle("Layer_{}".format(i) , fontsize=20)
    for i in range(1,features.shape[3]+1):

        plt.subplot(8,8,i) # Use 'plt' instead of 'pyplot'
        plt.imshow(fmap[0,:,:,i-1] , cmap='gray') # Use 'plt' instead of 'pyplot'

plt.show() # Use 'plt' instead of 'pyplot'
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
